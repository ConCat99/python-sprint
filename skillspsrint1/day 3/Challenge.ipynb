# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("gold_price_data.csv")

# %%
close_col = data["close"].to_numpy()

# %%
print(close_col)
# Out:
# [ 44.06999969  44.47000122  44.74000168 ... 311.         307.63000488
#  306.70999146]

# %%
sum = np.sum(close_col)
print('sum =', sum )
mean = np.mean(close_col)
print('mean =', mean)
median = np.median(close_col)
print('median =', median)
stand = np.std(close_col)
print('stand =', stand)
# Out:
# sum = 684502.9401092529
# mean = 131.25655610915683
# median = 123.9800033569336
# stand = 51.06827818298171

# %%
max = np.max(close_col)
min = np.min(close_col)
print(max,min)
range = max - min
print(range)
# Out:
# 315.0400085449219 41.02000045776367
# 274.0200080871582

# %%
date_col = data["date"].to_numpy()
print(date_col)
# Out:
# ['2004-11-18' '2004-11-19' '2004-11-22' ... '2025-08-08' '2025-08-11'
#  '2025-08-12']

# %%
#date_close_stk = np.vstack([close_col, date_col])
#print(date_close_stk)
# Out:
# [[44.06999969482422 44.470001220703125 44.7400016784668 ... 311.0
#   307.6300048828125 306.7099914550781]
#  ['2004-11-18' '2004-11-19' '2004-11-22' ... '2025-08-08' '2025-08-11'
#   '2025-08-12']]

# %%
close_max = np.where(close_col == max)
max_date = date_col[close_max]
print(max_date)
# Out:
# ['2025-06-13']

# %%
# Reshape into chunks of 30 days
reshaped = close_prices[:len(close_prices)//30*30].reshape(-1, 30)

# %%
first_month = data.head(31)
print(first_month)
last_month = data[-31:]
print(last_month)
# Out:
#           date       open       high        low      close  adj_close  \
# 0   2004-11-18  44.380001  44.380001  44.490002  44.070000  44.430000
# 1   2004-11-19  44.779999  44.779999  44.919998  44.470001  44.490002
# 2   2004-11-22  44.950001  44.950001  44.970001  44.740002  44.750000
# 3   2004-11-23  44.750000  44.750000  44.919998  44.720001  44.880001
# 4   2004-11-24  45.049999  45.049999  45.049999  44.790001  44.930000
# 5   2004-11-26  45.290001  45.290001  45.599998  45.060001  45.250000
# 6   2004-11-29  45.400002  45.400002  45.500000  45.080002  45.099998
# 7   2004-11-30  45.119999  45.119999  45.410000  44.820000  45.369999
# 8   2004-12-01  45.380001  45.380001  45.590000  45.259998  45.279999
# 9   2004-12-02  44.950001  44.950001  45.570000  44.680000  45.549999
# 10  2004-12-03  45.599998  45.599998  46.000000  44.799999  45.040001
# 11  2004-12-06  45.169998  45.169998  45.470001  45.110001  45.389999
# ...

# %%
## Ethan's answer

### 4. price differnces 
closing = arr[:,4]
opening = arr[:,1]
daily_change = closing - opening

print("daily change:", daily_change) 
print("max daily change:", daily_change.max())
print("min daily change:", daily_change.min())

### Which day had the largest increase?
date = arr[np.argmax(daily_change)][0]
print("largest increase:", date)

### Which day had the largest decrease? 
date = arr[np.argmin(daily_change)][0]
print("largest decrease", date)
