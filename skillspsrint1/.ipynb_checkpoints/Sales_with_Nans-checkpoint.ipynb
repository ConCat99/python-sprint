# %%
import pandas as pd
df = pd.read_csv("sales_with_nans.csv")#.to_string()
display(df)
# Out:
#           Group Customer_Segment  Sales_Before  Sales_After  \
# 0       Control       High Value    240.548359   300.007568
# 1     Treatment       High Value    246.862114   381.337555
# 2       Control       High Value    156.978084   179.330464
# 3       Control     Medium Value    192.126708   229.278031
# 4           NaN       High Value    229.685623          NaN
# ...         ...              ...           ...          ...
# 9995  Treatment              NaN    259.695935   415.181694
# 9996    Control       High Value    186.488285   216.225457
# 9997  Treatment        Low Value    208.107142   322.893351
# 9998  Treatment     Medium Value           NaN   431.974901
# 9999    Control        Low Value           NaN   124.402398
#
#       Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                        74.684767                          NaN            No
# 1                       100.000000                   100.000000           Yes
# ...

# %% [markdown]
# ### Cleaning Data

# %%
#Dropped all records with missing values
dropped_df = df.dropna(inplace= True)

df.head()
df.columns
# Out:
# Index(['Group', 'Customer_Segment', 'Sales_Before', 'Sales_After',
#        'Customer_Satisfaction_Before', 'Customer_Satisfaction_After',
#        'Purchase_Made'],
#       dtype='object')

# %% [markdown]
# ### Basic Statistics

# %%
total_sales = df.agg(
    total_before_sales = ("Sales_Before", "sum"), # Total sales before & after
    total_after_sales = ("Sales_After", "sum"),
    avg_before_sales = ("Sales_Before", "mean"), # Average sales before & after
    avg_after_sales = ("Sales_After", "mean"),
    avg_before_satisfaction = ('Customer_Satisfaction_Before', 'mean'), # Average satisfaction before & after
    avg_after_satisfaction = ('Customer_Satisfaction_After', 'mean'),
    min_before_sales = ('Sales_Before', 'min'),# Minimum and maximum sales values
    average_sales_diff = ("Sales_After", lambda column: coloumn.mean() - df["Sales_Before"].mean())# Calculate the change in average sales
    
)




df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 total_sales = df.agg(
#       2     total_before_sales = ("Sales_Before", "sum"), # Total sales before & after
#       3     total_after_sales = ("Sales_After", "sum"),
#       4     avg_before_sales = ("Sales_Before", "mean"), # Average sales before & after
#       5     avg_after_sales = ("Sales_After", "mean"),
#       6     avg_before_satisfaction = ('Customer_Satisfaction_Before', 'mean'), # Average satisfaction before & after
#       7     avg_after_satisfaction = ('Customer_Satisfaction_After', 'mean'),
#       8     min_before_sales = ('Sales_Before', 'min'),# Minimum and maximum sales values
#       9     average_sales_diff = ("Sales_After", lambda column: coloumn.mean() - df["Sales_Before"].mean())# Calculate the change in average sales
#      10
#      11 )
#      16 df.head()
#
# ...

# %%
# and change in satisfaction from before to after
